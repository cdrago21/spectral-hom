# %% [markdown]
# # Example 1: Two Gaussian photons
#
# In this example, we consider HOM interference between two photons, each with a Gaussian spectral profile. In Part a) we consider identical Gaussians and in Part b) we consider different Gaussians.

# %%
from spectral_hom.main import GaussianPulse, IndependentGaussianCoincidence

# %% [markdown]
# #### Example 1 a) Identical photons

# %%
# set the parameters for the Gaussian function 
gaussian_params = {'lambda_c': 780,  # center wavelength (nm)
                     'FWHM': 10  # Intensity Full-Width-Half-Max (ps)
                     }

# create a Gaussian pulse object
gaussian_pulse = GaussianPulse(gaussian_params)

# set Gaussian coincidence parameters 
gaussian_coincidence_params = {'gaussian_a': gaussian_pulse,
                               'gaussian_b': gaussian_pulse
                               }

# create independent gaussian coincidence object
gaussian_coincidence = IndependentGaussianCoincidence(gaussian_coincidence_params)

# plot temporal and spectral intensity and coincidence probability
gaussian_coincidence.plot_coincidence('HOM_identical_gaussians')
# Out:
# /Users/abranczyk/_github_repos/spectral-hom/spectral_hom/main.py:119: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(12, 3))

# %% [markdown]
# #### Example 1 b) Different Gaussians

# %%
# set first Gaussian parameters
gaussian_a_params = {'lambda_c': 780,  # center wavelength (nm)
                     'FWHM': 10  # Full-Width-Half-Max (ps)
                     }
# set second Gaussian parameters
gaussian_b_params = {'lambda_c': 780.02,  # center wavelength (nm)
                     'FWHM': 15,  # Full-Width-Half-Max (ps)
                     }

# create two Gaussian objects
gaussian_a = GaussianPulse(gaussian_a_params)
gaussian_b = GaussianPulse(gaussian_b_params)

# set Gaussian coincidence parameters 
gaussian_coincidence_params = {'gaussian_a': gaussian_a,
                               'gaussian_b': gaussian_b
                               }

# create independent gaussian coincidence object
gaussian_coincidence = IndependentGaussianCoincidence(gaussian_coincidence_params)

# plot temporal and spectral intensity and coincidence probability
gaussian_coincidence.plot_coincidence('HOM_different_gaussians')
# Out:
# /Users/abranczyk/_github_repos/spectral-hom/spectral_hom/main.py:119: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(12, 3))
