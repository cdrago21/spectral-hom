# %%
from main import DoubleGaussianJSA, DoubleGaussianCoincidence

# %%
double_gaussian_params = {'lambda_c': 780,  # center wavelength (nm)
                          'pulse_duration': 100,  # effective pulse duration  (ps)
                          'coherence_time': 100,  # coherence time  (ps)
                          }

double_gaussian = DoubleGaussianJSA(double_gaussian_params)


double_gaussian_coincidence = DoubleGaussianCoincidence({'double_gaussian': double_gaussian})

double_gaussian_coincidence.plot_coincidence()
# Out:
# 5.641895835477563e-09
# [[1.         0.99960008 0.99840128 ... 0.02320007 0.02145924 0.01983316]
#  [0.99960008 1.         0.99960008 ... 0.02506206 0.02320007 0.02145924]
#  [0.99840128 0.99960008 1.         ... 0.02705185 0.02506206 0.02320007]
#  ...
#  [0.02320007 0.02506206 0.02705185 ... 1.         0.99960008 0.99840128]
#  [0.02145924 0.02320007 0.02506206 ... 0.99960008 1.         0.99960008]
#  [0.01983316 0.02145924 0.02320007 ... 0.99840128 0.99960008 1.        ]]
# [[0.01831564 0.01983316 0.02145924 ... 0.99640647 0.99840128 0.99960008]
#  [0.01983316 0.02145924 0.02320007 ... 0.99840128 0.99960008 1.        ]
#  [0.02145924 0.02320007 0.02506206 ... 0.99960008 1.         0.99960008]
#  ...
#  [0.99640647 0.99840128 0.99960008 ... 0.02917626 0.02705185 0.02506206]
#  [0.99840128 0.99960008 1.         ... 0.02705185 0.02506206 0.02320007]
#  [0.99960008 1.         0.99960008 ... 0.02506206 0.02320007 0.02145924]]
